# %% [markdown]
# <img src="https://tradingcomdados.com/images/logotipo/logotipo-trading-com-dados.svg" width="300" align="left"/>

# %% [markdown]
# ##Pandas e Fundamentus

# %% [markdown]
# Documentação da lib utilizada:
# - https://pandas.pydata.org/docs/
# - https://pypi.org/project/fundamentus/
#
# - Esse código não é uma recomendação de investimento e deve ser utilizado somente para fins educacionais.
# - Autor: https://www.linkedin.com/in/arthur-camargo/

# %% [markdown]
# ###Importando Bibliotecas

# %%
# !pip install fundamentus
# !pip install plotly
# Out:
# Requirement already satisfied: fundamentus in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.2.0)
# Requirement already satisfied: lxml>=4.6.2 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fundamentus) (4.9.1)
# Requirement already satisfied: requests>=2.25.1 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fundamentus) (2.28.1)
# Requirement already satisfied: tabulate>=0.8.7 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fundamentus) (0.9.0)
# Requirement already satisfied: requests-cache>=0.5.2 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fundamentus) (1.0.0)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fundamentus) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.1.5->fundamentus) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.1.5->fundamentus) (1.23.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.1.5->fundamentus) (2022.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.25.1->fundamentus) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.25.1->fundamentus) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.25.1->fundamentus) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.25.1->fundamentus) (1.26.12)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-cache>=0.5.2->fundamentus) (1.4.3)
# Requirement already satisfied: cattrs>=22.2 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-cache>=0.5.2->fundamentus) (22.2.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-cache>=0.5.2->fundamentus) (3.1.1)
# Requirement already satisfied: attrs>=21.2 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-cache>=0.5.2->fundamentus) (22.2.0)
# Requirement already satisfied: exceptiongroup in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cattrs>=22.2->requests-cache>=0.5.2->fundamentus) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->fundamentus) (1.16.0)
# Requirement already satisfied: plotly in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (5.13.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kiool\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from plotly) (8.2.2)

# %%
import fundamentus
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ##Pandas

# %%
df = fundamentus.get_resultado()

# %%
df.head()
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        21.99  -19.20  2.43  2.382  0.0000  0.989 -31.71  86.56  -2.55
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        18.57    5.25  0.81  0.000  0.0752  0.000   0.00   0.00   0.00
# ABEV3        13.60   14.82  2.61  2.687  0.0561  1.553 -78.64  13.98 -12.74
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3      108.60     22.30   0.0275 -0.1180  0.0132 -0.1263  0.86
# ABCB3        0.00      0.00   0.0000  0.0000  0.0000  0.1537  0.00
# ABCB4        0.00      0.00   0.0000  0.0000  0.0000  0.1537  0.00
# ABEV3       13.23      9.74   0.1922  0.1868  0.1546  0.1764  0.93
# ABYA3       33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# AALR3       10973900.0  1.072550e+09      0.85  0.0116
# ABCB3              0.0  5.205390e+09      0.00  0.2753
# ABCB4       18402600.0  5.205390e+09      0.00  0.2753
# ABEV3      490789000.0  8.195560e+10      0.05  0.1331
# ABYA3              0.0  2.920600e+08      1.31  0.1641

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# Index(['AALR3', 'ABCB3', 'ABCB4', 'ABEV3', 'ABYA3', 'ACES3', 'ACES4', 'ADHM3',
#        'AEDU11', 'AEDU3',
#        ...
#        'WHRL4', 'WISA3', 'WISA4', 'WIZC3', 'WLMM3', 'WLMM4', 'WMBY3', 'WSON33',
#        'YDUQ3', 'ZAMP3'],
#       dtype='object', name='papel', length=969)

# %%
lista_de_ativos = df.index
lista_de_ativos
# Out:
# Index(['AALR3', 'ABCB3', 'ABCB4', 'ABEV3', 'ABYA3', 'ACES3', 'ACES4', 'ADHM3',
#        'AEDU11', 'AEDU3',
#        ...
#        'WHRL4', 'WISA3', 'WISA4', 'WIZC3', 'WLMM3', 'WLMM4', 'WMBY3', 'WSON33',
#        'YDUQ3', 'ZAMP3'],
#       dtype='object', name='papel', length=969)

# %%
df.columns
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
lista_de_indicadores = df.columns

# %%
lista_de_indicadores
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
type(lista_de_indicadores)
# Out:
# pandas.core.indexes.base.Index

# %%
#df.info retorna informaçãoes sobre o tipo de dados e ausência de nulls
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 969 entries, AALR3 to ZAMP3
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cotacao   969 non-null    float64
#  1   pl        969 non-null    float64
#  2   pvp       969 non-null    float64
#  3   psr       969 non-null    float64
#  4   dy        969 non-null    float64
#  5   pa        969 non-null    float64
#  6   pcg       969 non-null    float64
#  7   pebit     969 non-null    float64
#  8   pacl      969 non-null    float64
#  9   evebit    969 non-null    float64
#  10  evebitda  969 non-null    float64
#  11  mrgebit   969 non-null    float64
#  12  mrgliq    969 non-null    float64
#  13  roic      969 non-null    float64
#  14  roe       969 non-null    float64
#  15  liqc      969 non-null    float64
#  16  liq2m     969 non-null    float64
#  17  patrliq   969 non-null    float64
#  18  divbpatr  969 non-null    float64
#  19  c5y       969 non-null    float64
# dtypes: float64(20)
# memory usage: 159.0+ KB

# %%
#Seleção pela coluna

df['dy']
# Out:
# papel
# AALR3     0.0000
# ABCB3     0.0000
# ABCB4     0.0752
# ABEV3     0.0561
# ABYA3     0.0000
#            ...
# WLMM4     0.0507
# WMBY3     0.0000
# WSON33    0.0000
# YDUQ3     0.0167
# ZAMP3     0.0000
# Name: dy, Length: 969, dtype: float64

# %%
#Pandas Series outro tipo de estrutura de dados trabalhado no Pandas, um vetor de dados com labels em índice e coluna formato 1x1

type(df['dy'])
# Out:
# pandas.core.series.Series

# %%
df.sort_values(by='pl', ascending=True)
# Out:
# Multiples  cotacao        pl       pvp     psr      dy     pa     pcg   pebit  \
# papel
# GNDI3        66.95  -3584.82      5.84   3.423  0.0239  2.378   79.65   87.05
# PGMN3         3.65  -2633.82      0.69   0.176  0.0509  0.188    1.36    4.36
# PLDN4       486.00   -553.07      1.08   0.919  0.0000  0.611    1.07  -75.56
# MEGA3         8.97   -507.07      1.08   2.292  0.0000  0.331  -41.07   10.64
# ONCO3         6.92   -358.19      1.70   0.941  0.0000  0.471    5.56    9.91
# ...            ...       ...       ...     ...     ...    ...     ...     ...
# UBBR11       14.75   1201.81      3.91   0.000  0.0000  0.000    0.00    0.00
# GUAR4       151.00   1450.16     14.32   8.911  0.0000  4.952   19.35  280.18
# UBBR3        18.00   1466.61      4.77   0.000  0.0000  0.000    0.00    0.00
# MLFT4        22.39   6224.98     11.51  46.353  0.0000  5.854  100.42  103.43
# BBTG12        3.15  66496.50  26598.60   0.000  0.0000  0.000    0.00    0.00
#
# Multiples    pacl  evebit  evebitda  mrgebit  mrgliq    roic     roe   liqc  \
# papel
# GNDI3       -6.21   91.13     50.88   0.0393 -0.0009  0.0309 -0.0016   1.17
# PGMN3       -0.76    8.14      3.99   0.0404  0.0286  0.0543 -0.0003   1.41
# PLDN4        3.10  -33.12    -33.12  -0.0122 -0.0017 -0.0127 -0.0020  10.81
# MEGA3       -0.64   24.01     13.49   0.2155 -0.0033  0.0346 -0.0021   0.96
# ONCO3       -1.30   16.84     11.34   0.0949  0.0109  0.0557 -0.0047   1.42
# ...           ...     ...       ...      ...     ...     ...     ...    ...
# UBBR11       0.00    0.00      0.00   0.0000  0.0000  0.0000  0.0033   0.00
# GUAR4      307.97  286.37     88.71   0.0318  0.0061  0.0227  0.0099   1.62
# UBBR3        0.00    0.00      0.00   0.0000  0.0000  0.0000  0.0033   0.00
# MLFT4      -26.71  106.22     78.73   0.4482  0.0126  0.0735  0.0018   1.27
# BBTG12       0.00    0.00      0.00   0.0000  0.0000  0.0000  0.4000   0.00
#
# Multiples       liq2m       patrliq  divbpatr     c5y
# papel
# GNDI3             0.0  7.116080e+09      0.53  0.2523
# PGMN3       3209680.0  2.334550e+09      0.67  0.0976
# PLDN4             0.0  2.899390e+08      0.01  0.1026
# MEGA3      10591300.0  5.151090e+09      1.65  9.2252
# ONCO3      10406500.0  2.014190e+09      1.48  0.0000
# ...               ...           ...       ...     ...
# UBBR11            0.0  1.031720e+10      0.00  0.1058
# GUAR4             0.0  5.263090e+09      0.78  0.0249
# UBBR3             0.0  1.031720e+10      0.00  0.1058
# MLFT4             0.0  4.093330e+09      0.76  0.0843
# BBTG12            0.0  1.000000e+04      0.00  0.0000
#
# [969 rows x 20 columns]

# %%
#loc localiza linhas e colunas pelo seu label
df.loc['GNDI3']
# Out:
# Multiples
# cotacao     6.695000e+01
# pl         -3.584820e+03
# pvp         5.840000e+00
# psr         3.423000e+00
# dy          2.390000e-02
# pa          2.378000e+00
# pcg         7.965000e+01
# pebit       8.705000e+01
# pacl       -6.210000e+00
# evebit      9.113000e+01
# evebitda    5.088000e+01
# mrgebit     3.930000e-02
# mrgliq     -9.000000e-04
# roic        3.090000e-02
# roe        -1.600000e-03
# liqc        1.170000e+00
# liq2m       0.000000e+00
# patrliq     7.116080e+09
# divbpatr    5.300000e-01
# c5y         2.523000e-01
# Name: GNDI3, dtype: float64

# %%
df.loc[['GNDI3'],['pl']]
# Out:
# Multiples       pl
# papel
# GNDI3     -3584.82

# %%
#iloc localiza linha e coluna pela sua posição, lembre-se python inicia a indexação em 0 (primeira posição)
df.iloc[[0],[0]]
# Out:
# Multiples  cotacao
# papel
# AALR3        21.99

# %%
df.loc[['GNDI3', 'MELK3'],['dy']]
# Out:
# Multiples      dy
# papel
# GNDI3      0.0239
# MELK3      0.0691

# %%
#exemplo de slicing com loc, lembre-se da estrutura linha (i) coluna (j), df.loc[[i],[j]] 

df.loc['GNDI3':'GPAR3', 'pl':'pa']
# Out:
# Multiples       pl   pvp     psr      dy     pa
# papel
# GNDI3     -3584.82  5.84   3.423  0.0239  2.378
# GOAU3         3.14  0.71   0.143  0.1040  0.157
# GOAU4         3.35  0.76   0.152  0.0974  0.168
# GOLL4        -0.72 -0.15   0.246  0.0000  0.200
# GPAR3         4.13  3.00  18.512  0.5051  2.731

# %%
#filtros usados em conjunto através do operador & 

df[(df.pl > 15) & (df.dy > 0.05)]
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AGRO3        26.14   21.50  1.30  2.105  0.2010  0.794   4.21  15.33 -63.73
# CEPE5        40.12   19.07  1.94  0.377  0.0934  0.227   2.87   2.61  -0.38
# CEPE6        43.00   20.44  2.08  0.405  0.0959  0.243   3.08   2.80  -0.40
# CPLE11       33.27   20.73  0.87  0.795  0.1307  0.365   4.86   4.90  -1.02
# CPLE3         6.15   19.16  0.80  0.735  0.1309  0.338   4.49   4.53  -0.94
# CPLE6         6.76   21.06  0.88  0.808  0.1310  0.371   4.94   4.97  -1.04
# CRPG3        55.00   15.07  1.75  1.749  0.0865  1.360   2.94  17.37   3.80
# DESK3         8.92   16.79  0.85  1.223  4.9726  0.322   9.50   4.91  -0.74
# EEEL3       421.01   23.61  3.12  3.040  0.2999  0.948   5.56   5.46  -2.18
# EEEL4       410.00   23.00  3.04  2.961  0.3387  0.923   5.41   5.31  -2.12
# EQPA6        10.69   17.07  5.43  2.733  0.0826  1.858  14.03  10.09  -6.44
# FLRY3        14.78   15.61  2.83  1.243  0.0588  0.800  10.77   7.31  -1.80
# GEPA3        24.39   15.47  1.12  1.702  0.0983  0.613  -5.03   6.55  -1.73
# GEPA4        25.00   15.86  1.14  1.744  0.0959  0.628  -5.16   6.72  -1.78
# LCAM3        24.15   17.42  2.47  1.726  0.0515  0.575   5.09   5.57  -1.38
# MODL3         1.70   42.02  0.96  0.000  0.0705  0.000   0.00   0.00   0.00
# PATI3        50.60   21.74  1.44  0.519  0.0575  0.637   1.19  22.53   2.35
# PATI4        51.99   22.34  1.48  0.534  0.0560  0.655   1.22  23.15   2.41
# PORT3        10.40   16.26  1.92  1.651  0.0579  0.784  30.78   6.55  -1.81
# RAIZ4         2.80  300.78  1.37  0.119  0.0529  0.276   3.69   8.77  -0.86
# STBP3         8.23   16.92  3.32  3.728  0.0801  1.433  13.71  13.15  -3.99
# VIVT3        39.39   16.04  0.96  1.364  0.0771  0.550 -13.41  10.86  -1.96
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AGRO3       18.55     12.59   0.1373  0.0979  0.0604  0.0607  1.99
# CEPE5        8.33      6.31   0.1446  0.0198  0.1000  0.1018  1.40
# CEPE6        8.52      6.45   0.1446  0.0198  0.1000  0.1018  1.40
# CPLE11       7.32      5.45   0.1624  0.0403  0.0856  0.0419  1.54
# CPLE3        6.95      5.18   0.1624  0.0403  0.0856  0.0419  1.54
# CPLE6        7.40      5.51   0.1624  0.0403  0.0856  0.0419  1.54
# CRPG3       15.68     11.62   0.1007  0.1161  0.0969  0.1162  4.91
# DESK3        8.54      5.22   0.2494  0.0853  0.0770  0.0503  1.23
# EEEL3        6.42      6.42   0.5572  0.1190  0.1894  0.1323  2.91
# EEEL4        6.28      6.28   0.5572  0.1190  0.1894  0.1323  2.91
# EQPA6       11.07      9.50   0.2708  0.1601  0.2378  0.3180  1.56
# FLRY3       11.13      7.00   0.1701  0.0800  0.1300  0.1816  1.38
# GEPA3        8.78      5.73   0.2597  0.1100  0.1125  0.0722  0.44
# GEPA4        8.95      5.84   0.2597  0.1100  0.1125  0.0722  0.44
# LCAM3        9.94      7.57   0.3100  0.0991  0.1354  0.1421  1.48
# MODL3        0.00      0.00   0.0000  0.0000  0.0000  0.0227  0.00
# PATI3       22.93     18.96   0.0231  0.0239  0.0522  0.0663  2.83
# PATI4       23.55     19.47   0.0231  0.0239  0.0522  0.0663  2.83
# PORT3       10.08      7.35   0.2518  0.1064  0.1297  0.1182  1.19
# RAIZ4       20.63      5.49   0.0135  0.0006  0.0406  0.0045  1.19
# STBP3       12.36      8.76   0.2835  0.2204  0.1323  0.1964  1.99
# VIVT3       13.68      4.42   0.1256  0.0845  0.0551  0.0597  0.78
#
# Multiples         liq2m       patrliq  divbpatr     c5y
# papel
# AGRO3      1.128940e+07  2.051180e+09      0.43  0.3367
# CEPE5      0.000000e+00  1.543000e+09      4.86  1.2105
# CEPE6      0.000000e+00  1.543000e+09      4.86  1.2105
# CPLE11     1.187010e+07  2.096970e+10      0.64  0.1289
# CPLE3      7.515030e+06  2.096970e+10      0.64  0.1289
# CPLE6      1.019240e+08  2.096970e+10      0.64  0.1289
# CRPG3      0.000000e+00  9.112660e+08      0.01  0.1263
# DESK3      1.441370e+06  9.209070e+08      0.95  0.0000
# EEEL3      0.000000e+00  1.301400e+09      0.79  0.0595
# EEEL4      0.000000e+00  1.301400e+09      0.79  0.0595
# EQPA6      0.000000e+00  4.349990e+09      0.97  0.1306
# FLRY3      4.034790e+07  1.914900e+09      1.89  0.1422
# GEPA3      5.948500e+02  2.063530e+09      0.46 -0.0039
# GEPA4      1.572630e+04  2.063530e+09      0.46 -0.0039
# LCAM3      0.000000e+00  4.965670e+09      2.38  0.3855
# MODL3      7.895820e+06  1.252920e+09      0.00  0.4437
# PATI3      1.911880e+03  8.403730e+08      0.74  0.2836
# PATI4      0.000000e+00  8.403730e+08      0.74  0.2836
# PORT3      2.324040e+06  2.379580e+09      1.18  0.0000
# RAIZ4      1.068210e+08  2.119640e+10      2.08  0.1546
# STBP3      4.140560e+07  2.139970e+09      0.15  0.2003
# VIVT3      1.054190e+08  6.840370e+10      0.28  0.0197

# %%
df.loc[:,['pl']] > 10
# Out:
# Multiples     pl
# papel
# AALR3      False
# ABCB3      False
# ABCB4      False
# ABEV3       True
# ABYA3      False
# ...          ...
# WLMM4      False
# WMBY3      False
# WSON33     False
# YDUQ3      False
# ZAMP3      False
#
# [969 rows x 1 columns]

# %% [markdown]
# ##Exercício
#
# Criar um gráfico que sumarize um grupo de métricas fundamentalistas de um determinado setor

# %%
#lista de empresas através do código do setor

fundamentus.list_papel_setor(8)
# Out:
# ['PGMN3',
#  'PCAR3',
#  'PFRM3',
#  'DMVF3',
#  'GMAT3',
#  'BLAU3',
#  'HYPE3',
#  'CRFB3',
#  'PNVL3',
#  'VVEO3',
#  'ASAI3',
#  'RADL3']

# %%
setor = fundamentus.list_papel_setor(8)
setor
# Out:
# ['PGMN3',
#  'PCAR3',
#  'PFRM3',
#  'DMVF3',
#  'GMAT3',
#  'BLAU3',
#  'HYPE3',
#  'CRFB3',
#  'PNVL3',
#  'VVEO3',
#  'ASAI3',
#  'RADL3']

# %%
df.query('index in @setor')
# Out:
# Multiples  cotacao       pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# ASAI3        17.87    19.76  6.19  0.442  0.0091  0.594 -10.78   6.35  -1.07
# BLAU3        30.03    14.85  2.96  3.829  0.0283  2.156   4.12  11.87   5.40
# CRFB3        12.79    15.47  1.33  0.262  0.0264  0.292  -6.76   5.49  -0.97
# DMVF3         3.52     7.63  0.21  0.127  0.0000  0.123   2.67   1.46  -0.88
# GMAT3         5.70    11.97  1.69  0.579  0.0000  0.949   2.08  10.60   4.09
# HYPE3        41.20    15.38  2.45  3.458  0.0299  1.099   7.90  10.60  -5.71
# PCAR3        14.51   -22.79  0.34  0.226  0.0244  0.089   0.36   3.90  -2.53
# PFRM3         3.25     4.61  0.33  0.054  0.0533  0.096   0.46   1.22   2.50
# PGMN3         3.65 -2633.82  0.69  0.176  0.0509  0.188   1.36   4.36  -0.76
# PNVL3        10.06    17.71  1.39  0.398  0.0221  0.589   2.43  14.42 -32.60
# RADL3        24.00    39.80  7.42  1.364  0.0106  2.307  12.35  22.61 -17.98
# VVEO3        17.80    19.61  2.23  0.582  0.0244  0.533   2.11   9.55  -3.09
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ASAI3        8.13      6.45   0.0696  0.0224  0.1744  0.3131  0.86
# BLAU3       11.13     10.61   0.3227  0.2558  0.2684  0.1991  4.52
# CRFB3        7.12      5.27   0.0476  0.0194  0.0809  0.0858  0.91
# DMVF3        1.26      0.70   0.0871  0.0167  0.1024  0.0276  1.20
# GMAT3       11.76      9.21   0.0546  0.0489  0.1256  0.1412  3.20
# HYPE3       13.34     12.48   0.3263  0.2251  0.1203  0.1594  1.63
# PCAR3        6.00      2.97   0.0580 -0.0002  0.0272 -0.0149  1.61
# PFRM3        2.95      2.09   0.0445  0.0131  0.1194  0.0724  1.45
# PGMN3        8.14      3.99   0.0404  0.0286  0.0543 -0.0003  1.41
# PNVL3       21.42      7.76   0.0276  0.0225  0.0516  0.0783  1.77
# RADL3       23.68     12.87   0.0603  0.0349  0.1404  0.1865  1.50
# VVEO3       12.02     11.46   0.0610  0.0297  0.0949  0.1139  1.75
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# ASAI3      198637000.0  3.896000e+09      3.23  0.2116
# BLAU3        7374670.0  1.822160e+09      0.17  0.1629
# CRFB3       99361900.0  2.027000e+10      0.94  0.1662
# DMVF3         179640.0  8.465540e+08      0.03  0.2918
# GMAT3       40974800.0  7.455610e+09      0.42  0.3823
# HYPE3      177238000.0  1.064580e+10      0.90  0.2216
# PCAR3       78356100.0  1.154500e+10      0.51 -0.1971
# PFRM3         598336.0  1.205210e+09      0.57  0.1605
# PGMN3        3209680.0  2.334550e+09      0.67  0.0976
# PNVL3        4624520.0  1.091000e+09      0.82  0.1238
# RADL3      132758000.0  5.340860e+09      0.43  0.1814
# VVEO3        2703940.0  2.280440e+09      1.46  0.4078

# %%
df.query('index in @setor').loc[:,['mrgebit', 'mrgliq', 'roic', 'roe']]
# Out:
# Multiples  mrgebit  mrgliq    roic     roe
# papel
# ASAI3       0.0696  0.0224  0.1744  0.3131
# BLAU3       0.3227  0.2558  0.2684  0.1991
# CRFB3       0.0476  0.0194  0.0809  0.0858
# DMVF3       0.0871  0.0167  0.1024  0.0276
# GMAT3       0.0546  0.0489  0.1256  0.1412
# HYPE3       0.3263  0.2251  0.1203  0.1594
# PCAR3       0.0580 -0.0002  0.0272 -0.0149
# PFRM3       0.0445  0.0131  0.1194  0.0724
# PGMN3       0.0404  0.0286  0.0543 -0.0003
# PNVL3       0.0276  0.0225  0.0516  0.0783
# RADL3       0.0603  0.0349  0.1404  0.1865
# VVEO3       0.0610  0.0297  0.0949  0.1139

# %%
varejo = df.query('index in @setor').loc[:,['mrgebit', 'mrgliq', 'roic', 'roe']]
varejo
# Out:
# Multiples  mrgebit  mrgliq    roic     roe
# papel
# ASAI3       0.0696  0.0224  0.1744  0.3131
# BLAU3       0.3227  0.2558  0.2684  0.1991
# CRFB3       0.0476  0.0194  0.0809  0.0858
# DMVF3       0.0871  0.0167  0.1024  0.0276
# GMAT3       0.0546  0.0489  0.1256  0.1412
# HYPE3       0.3263  0.2251  0.1203  0.1594
# PCAR3       0.0580 -0.0002  0.0272 -0.0149
# PFRM3       0.0445  0.0131  0.1194  0.0724
# PGMN3       0.0404  0.0286  0.0543 -0.0003
# PNVL3       0.0276  0.0225  0.0516  0.0783
# RADL3       0.0603  0.0349  0.1404  0.1865
# VVEO3       0.0610  0.0297  0.0949  0.1139

# %%
fig = make_subplots(rows=2,
                    cols=2,
                    row_heights=[4,4],
                    column_widths=[4,4],
                    subplot_titles=('Margem EBTIDA', 'Margem Líquida', 'ROIC', 'ROE'),
                    shared_xaxes=False)
fig.add_trace(go.Bar(name='Margem_Ebtida', x=varejo.index, y=varejo['mrgebit']), row=1, col=1)
fig.add_trace(go.Bar(name='Margem_Liquida', x=varejo.index, y=varejo['mrgliq']), row=1, col=2)
fig.add_trace(go.Bar(name='ROIC', x=varejo.index, y=varejo['roic']), row=2, col=1)
fig.add_trace(go.Bar(name='ROE', x=varejo.index, y=varejo['roe']), row=2, col=2)
fig.update_layout(title_text='<b>Overview Rentabilidade Varejo<b>', 
                  template='plotly_dark',#template pré-definido da plotly
                  showlegend=False, #esconder ou mostrar legenda
                  height=500, #altura
                  width=900) #largura
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kiool\OneDrive\Documentos\GitHub\Python\PyFi\Cópia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb Cell 34 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=9'>10</a> fig.add_trace(go.Bar(name='ROE', x=varejo.index, y=varejo['roe']), row=2, col=2)
#      <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=10'>11</a> fig.update_layout(title_text='<b>Overview Rentabilidade Varejo<b>',
#      <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=11'>12</a>                   template='plotly_dark',#template pré-definido da plotly
#      <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=12'>13</a>                   showlegend=False, #esconder ou mostrar legenda
#      <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=13'>14</a>                   height=500, #altura
#      <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=14'>15</a>                   width=900) #largura
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kiool/OneDrive/Documentos/GitHub/Python/PyFi/C%C3%B3pia_de_Live_08_09_2022_Pandas_Fundamentus.ipynb#X46sZmlsZQ%3D%3D?line=15'>16</a> fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\basedatatypes.py:3390, in BaseFigure.show(self, *args, **kwargs)
#    3357 """
#    3358 Show a figure using either the default renderer(s) or the renderer(s)
#    3359 specified by the renderer argument
#    (...)
#    3386 None
#    3387 """
#    3388 import plotly.io as pio
# -> 3390 return pio.show(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
varejo2 = df.query('index in @setor').loc[:,['pl', 'pvp', 'evebitda', 'dy']]
varejo2
# Out:
# Multiples     pl   pvp  evebitda      dy
# papel
# ASAI3      16.12  7.78      7.85  0.0090
# BLAU3      18.88  3.44     12.31  0.0222
# CRFB3      16.16  2.14     10.08  0.0270
# DMVF3      13.71  0.30      1.11  0.0000
# GMAT3      16.52  2.10     11.33  0.0000
# HYPE3      20.27  2.70     14.56  0.0284
# PCAR3       3.10  0.42      2.02  0.0161
# PFRM3       4.82  0.40      3.08  0.0727
# PGMN3      17.83  1.05      4.41  0.0000
# PNVL3      22.01  1.69      9.47  0.0156
# RADL3      45.67  7.47     13.45  0.0110
# VVEO3      17.53  2.24     12.18  0.0232

# %%
#ORDENANDO OS VALORES

#Para fazer isso deixar o shared xaxes = False  e adicionar o fig.update_xaxes(categoryorder='total descending')

fig = make_subplots(rows=2,
                    cols=2,
                    row_heights=[5,5],
                    column_widths=[3,3],
                    subplot_titles=('Preço/Lucro', 'P/VP', 'EV/EBTIDA', 'Dividend Yeld'),
                    shared_xaxes=False)
fig.add_trace(go.Bar(name='Margem_Ebtida', x=varejo2.index, y=varejo2['pl']), row=1, col=1)
fig.add_trace(go.Bar(name='Margem_Liquida', x=varejo2.index, y=varejo2['pvp']), row=1, col=2)
fig.add_trace(go.Bar(name='ROIC', x=varejo2.index, y=varejo2['evebitda']), row=2, col=1)
fig.add_trace(go.Bar(name='ROE', x=varejo2.index, y=varejo2['dy']), row=2, col=2)
fig.update_layout(title_text='<b>Avaliação por Múltiplos Varejo<b>', 
                  template='plotly_dark',#template pré-definido da plotly
                  showlegend=False, #esconder ou mostrar legenda
                  height=500, #altura
                  width=900) #largura
fig.update_xaxes(categoryorder='total descending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e5ee98b0-8c77-467d-b8b0-44851f1d45c1" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5ee98b0-8c77-467d-b8b0-44851f1d45c1")) {                    Plotly.newPlot(                        "e5ee98b0-8c77-467d-b8b0-44851f1d45c1",                        [{"name":"Margem_Ebtida","x":["ASAI3","BLAU3","CRFB3","DMVF3","GMAT3","HYPE3","PCAR3","PFRM3","PGMN3","PNVL3","RADL3","VVEO3"],"y":[16.12,18.88,16.16,13.71,16.52,20.27,3.1,4.82,17.83,22.01,45.67,17.53],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Margem_Liquida","x":["ASAI3","BLAU3","CRFB3","DMVF3","GMAT3","HYPE3","PCAR3","PFRM3","PGMN3","PNVL3","RADL3","VVEO3"],"y":[7.78,3.44,2.14,0.3,2.1,2.7,0.42,0.4,1.05,1.69,7.47,2.24],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"ROIC","x":["ASAI3","BLAU3","CRFB3","DMVF3","GMAT3","HYPE3","PCAR3","PFRM3","PGMN3","PNVL3","RADL3","VVEO3"],"y":[7.85,12.31,10.08,1.11,11.33,14.56,2.02,3.08,4.41,9.47,13.45,12.18],"type":"bar","xaxis":"x3","yaxis":"y3"},{"name":"ROE","x":["ASAI3","BLAU3","CRFB3","DMVF3","GMAT3","HYPE3","PCAR3","PFRM3","PGMN3","PNVL3","RADL3","VVEO3"],"y":[0.009000000000000001,0.0222,0.027000000000000003,0.0,0.0,0.028399999999999998,0.0161,0.0727,0.0,0.015600000000000001,0.011000000000000001,0.0232],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111, ...
