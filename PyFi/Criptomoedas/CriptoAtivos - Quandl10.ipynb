# %%
# !pip install upgrade -q quandl
# Out:
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\kiool\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\kiool\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import quandl
import pandas
import matplotlib.pyplot as plt
import datetime

# %%
quandl.ApiConfig.api_key = "gLyyk3r4MQAFEL9nSPWx"

# %%
localbtcbrl = quandl.get('LOCALBTC/BRL', start_date = '2015-01-01', end_date='2024-01-01')
print(localbtcbrl)
# Out:
#               24h Average    12h Average       Last  Volume (BTC)
# Date
# 2015-01-02     898.859545     898.859545     887.04     11.300000
# 2015-01-05     849.760000     849.760000     849.76      1.180000
# 2015-01-06     810.404154     807.674486     773.67      5.430000
# 2015-01-08     847.949207     847.949207     848.87      7.220000
# 2015-01-09     945.400000     945.400000     945.40      2.120000
# ...                   ...            ...        ...           ...
# 2021-05-03  317943.290000  317854.070000  322268.77      0.936910
# 2021-05-04  307385.450000  306828.050000  304998.93      0.631305
# 2021-05-06  309054.670000  307504.240000  307560.50      1.067478
# 2021-05-08  311419.610000  311566.880000  318282.97      0.599054
# 2021-05-09  312706.810000  312452.830000  314140.90      0.297415
#
# [2146 rows x 4 columns]

# %%
localbtcbrl['Last'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
btcbrl = quandl.get('LOCALBTC/BRL')
btcbrl['Last'].tail(14).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ltc = quandl.get('GDAX/LTC_USD')
ltc['High'].tail(5).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ethusd = quandl.get('GDAX/ETH_USD')
ethusd['High'].tail(5).plot()
# Out:
# <Axes: xlabel='Date'>
