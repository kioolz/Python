# %%
from datetime import datetime
import pandas as pd 
import yfinance as yf 
import requests 
from bs4 import BeautifulSoup 
import plotly
import openpyxl

# %%
url = 'https://www.fundsexplorer.com.br/ranking'

# %%
agent = {"User-Agent":"Mozilla/5.0"}
response = requests.get(url)

soup = BeautifulSoup(response.text, 'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table), decimal=',', thousands='.')[0]
df
# Out:
#     Códigodo fundo                Setor  Preço Atual  Liquidez Diária  \
# 0           FIVN11            Shoppings      R$ 4,30          38280.0
# 1           BZLI11  Títulos e Val. Mob.     R$ 15,39             50.0
# 2           XTED11   Lajes Corporativas      R$ 7,11          17970.0
# 3           ALMI11   Lajes Corporativas  R$ 1.350,00            580.0
# 4           DOMC11   Lajes Corporativas    R$ 439,00            420.0
# ..             ...                  ...          ...              ...
# 203         CRFF11  Títulos e Val. Mob.     R$ 81,20           4690.0
# 204         RBBV11  Títulos e Val. Mob.     R$ 97,06           2810.0
# 205         CXRI11              Híbrido    R$ 102,52          19150.0
# 206         CTXT11   Lajes Corporativas     R$ 38,40           2590.0
# 207         GGRC11            Logística    R$ 139,75         107330.0
#
#     Dividendo DividendYield DY (3M)Acumulado DY (6M)Acumulado  \
# 0     R$ 0,00         0,00%            0,00%            0,00%
# 1     R$ 0,00         0,00%            0,00%            0,00%
# 2     R$ 0,00         0,00%            0,00%            0,00%
# 3     R$ 0,00         0,00%            0,00%            0,00%
# 4     R$ 0,00         0,00%            0,00%            0,00%
# ..        ...           ...              ...              ...
# 203   R$ 0,45         0,55%            1,54%            3,08%
# 204   R$ 1,43         1,46%            3,51%            4,94%
# 205   R$ 0,60         0,53%            1,54%            2,86%
# 206   R$ 0,10         0,26%            1,30%            3,64%
# 207   R$ 0,97         0,69%            1,74%            3,21%
#
#     DY (12M)Acumulado DY (3M)Média  ...     PatrimônioLíq.          VPA P/VPA  \
# 0               0,00%        0,00%  ...   R$ 67.073.539,56      R$ 7,13  0.60
# 1               0,00%        0,00%  ...  R$ 431.537.173,46     R$ 11,71  1.31
# 2               0,00%        0,00%  ...   R$ 26.976.019,49     R$ 15,05  0.47
# 3               0,00%        0,00%  ...  R$ 223.277.514,45  R$ 2.008,31  0.67
# 4               0,00%        0,00%  ...  R$ 263.586.942,55  R$ 1.078,59  0.41
# ..                ...          ...  ...                ...          ...   ...
# 203             6,00%        0,51%  ...   R$ 65.445.026,35     R$ 94,84  0.86
# 204             7,19%        1,17%  ...  R$ 126.535.571,48    R$ 100,89  0.96
# 205             7,41%        0,51%  ...  R$ 153.040.983,83     R$ 97,12  1.06
# 206             8,17%        0,43%  ...  R$ 125.593.977,69     R$ 48,41  0.79
# 207             6,39%        0,58%  ...  R$ 943.299.423,00    R$ 124,46  1.12
#
#     DYPatrimonial VariaçãoPatrimonial Rentab. Patr.no Período  \
# 0             NaN                 NaN                     NaN
# 1             NaN                 NaN                     NaN
# 2             NaN                 NaN                     NaN
# 3             NaN                 NaN                     NaN
# 4             NaN                 NaN                     NaN
# ..            ...                 ...                     ...
# 203           NaN                 NaN                     NaN
# 204           NaN                 NaN                     NaN
# 205           NaN                 NaN                     NaN
# 206           NaN                 NaN                     NaN
# 207           NaN                 NaN                     NaN
#
#     Rentab. Patr.Acumulada VacânciaFísica  VacânciaFinanceira QuantidadeAtivos
# 0                      NaN         56,00%                 NaN                1
# 1                      NaN            NaN                 NaN                0
# 2                      NaN        100,00%             100,00%                1
# 3                      NaN         68,15%                 NaN                1
# 4                      NaN         23,44%                 NaN                1
# ..                     ...            ...                 ...              ...
# 203                    NaN            NaN                 NaN                0
# 204                    NaN            NaN                 NaN                1
# 205                    NaN            NaN                 NaN                0
# 206                    NaN         58,00%                 NaN                1
# 207                    NaN          0,00%               0,00%               15
#
# [208 rows x 26 columns]

# %%
df = pd.read_csv('fundos_imob.csv.csv', decimal=',', thousands='.')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2c413726a122> in <module>
# ----> 1 df = pd.read_csv('fundos_imob.csv.csv', decimal=',', thousands='.')
#       2 df
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'fundos_imob.csv.csv' does not exist: b'fundos_imob.csv.csv'

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# codigofundo             object
# Setor                   object
# precoatual              object
# liquidezdiaria         float64
# dividendo               object
# dy                     float64
# dy3acum                float64
# dy6acum                float64
# dy12acum               float64
# dy3meses               float64
# dy6meses               float64
# dy12meses              float64
# dyano                  float64
# variacaopreco          float64
# rentperiodo            float64
# retacumulada           float64
# patrimonioliquido       object
# VPA                     object
# P/VPA                  float64
# dypatrimonial          float64
# variacaopatrimonial    float64
# rentpatrperiodo        float64
# rentpatriacum          float64
# vacanciafisica         float64
# vacanciafinanceira     float64
# QuantidadeAtivos         int64
# dtype: object

# %%
symbols = df['codigofundo'] + '.SA'
symbols
# Out:
# 0      FIVN11.SA
# 1      BZLI11.SA
# 2      XTED11.SA
# 3      ALMI11.SA
# 4      DOMC11.SA
#          ...
# 195    BLCP11.SA
# 196    MORE11.SA
# 197    MGCR11.SA
# 198    TRNT11.SA
# 199    GCFF11.SA
# Name: codigofundo, Length: 200, dtype: object

# %%
start = datetime(2015, 12, 1)
end = datetime.today()

# %%
def pega_fundos(name):
    stock = yf.download(name, start = start, end = end)
    return stock

# %%
stock_dict = {}

for symbol in symbols:
    try:
        stock_dict[symbol] = pega_fundos(symbol)
    except:
        print('NAO DEU CERTO PARA O TICK', symbol)

print("TERMINOU")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - NVIF11B.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GALG11.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SPVJ11.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - HREC11.SA: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# TERMINOU

# %%
stock_dict['BTCR11.SA']
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-01-04  98.430000  98.430000  98.430000  98.430000  98.430000    2250
# 2019-01-07  98.430000  98.430000  98.430000  98.430000  98.430000       0
# 2019-01-08  98.430000  98.430000  98.430000  98.430000  98.430000       0
# 2019-01-09  98.430000  98.430000  98.430000  98.430000  98.430000       0
# 2019-01-10  98.430000  98.430000  98.430000  98.430000  98.430000       0
# ...               ...        ...        ...        ...        ...     ...
# 2020-12-16  83.919998  84.000000  83.500000  84.000000  84.000000    3142
# 2020-12-17  84.230003  85.000000  83.900002  84.010002  84.010002    3908
# 2020-12-18  84.010002  84.199997  83.660004  84.169998  84.169998    5547
# 2020-12-21  84.169998  84.400002  84.169998  84.379997  84.379997    1516
# 2020-12-22  84.360001  84.849998  83.910004  84.849998  84.849998    3047
#
# [487 rows x 6 columns]

# %%
returns = pd.DataFrame()

for key in stock_dict.keys():
    returns[key] = stock_dict[key]['Adj Close'].pct_change()

returns.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bdadc243a7cd> in <module>
#       1 returns = pd.DataFrame()
#       2
# ----> 3 for key in stock_dict.keys():
#       4     returns[key] = stock_dict[key]['Adj Close'].pct_change()
#       5
#
# NameError: name 'stock_dict' is not defined

# %%
discount_dict = {}

def calcula_desconto(df):
    max_price = df['Adj Close'].describe()['75%']
    last_price = df['Adj Close'].iloc[-1]
    return (last_price - max_price)/max_price

# %%
for tick in stock_dict.keys():
    try:
        discount_dict[tick] = calcula_desconto(stock_dict[tick])
    except:
        discount_dict[tick] = 0

discount_dict
# Out:
# {'FIVN11.SA': -0.4423357684049922,
#  'BZLI11.SA': -0.05194800369332062,
#  'XTED11.SA': -0.6846699229646434,
#  'ALMI11.SA': -0.34060624815333007,
#  'DOMC11.SA': -0.20473898687084102,
#  'PABY11.SA': -0.41845812280978334,
#  'RBCB11.SA': -0.959986909780055,
#  'RBDS11.SA': -0.9340397907524413,
#  'KNRE11.SA': -0.638974360930614,
#  'FMOF11.SA': -0.3151497520423943,
#  'ATSA11.SA': -0.9000789441560444,
#  'XPHT11.SA': -0.08411409667814114,
#  'HTMX11.SA': -0.23130385503062362,
#  'BPML11.SA': -0.025027620034519003,
#  'RBGS11.SA': -0.14642878675235643,
#  'WPLZ11.SA': 0.0036191446882132008,
#  'GSFI11.SA': -0.12987013308711196,
#  'FVPQ11.SA': -0.28247632776131787,
#  'NEWU11.SA': -0.08998882541087057,
#  'HBTT11.SA': 0.0,
#  'PRSV11.SA': -0.6477936403410176,
#  'CARE11.SA': -0.588571412222726,
#  'FAMB11B.SA': -0.65872164280022,
#  'DRIT11B.SA': -0.10666666666666667,
#  'ONEF11.SA': 0.013164509970038022,
#  'MBRF11.SA': -0.15864378401004606,
#  'LASC11.SA': 0.0,
#  'RCRB11.SA': -0.03932618176585632,
#  'OULG11.SA': 0.0,
#  'WTSP11B.SA': -0.2861333211263021,
#  'OUFF11.SA': -0.15288661681499677,
#  'OUCY11.SA': -0.12710656490422748,
#  'ARCT11.SA': 0.0,
#  'CJCT11.SA': 0.0,
#  'XPIN11.SA': -0.032760002041863266,
#  'FCFL11.SA': -0.9449755956143809,
#  'XPML11.SA': 0.027297286299971846,
#  'ALZR11.SA': 0.054318353831361604,
#  'CNES11.SA': -0.37128085123372734,
#  'FLRP11.SA': 0.21308333785445602,
#  'EDGA11.SA': -0.4393741636920814,
#  'RZTR11.SA': 0.0,
#  'DMAC11.SA': -0.7996703203182169,
#  'NVIF11B.SA': 0,
#  'MFAI11.SA': 0.0,
#  'VLOL11.SA': 0.0014727690537670445,
#  'RFOF11.SA': 0.01448407387731829,
#  'RBCO11.SA': -0.006338897818507771,
#  'FIIP11B.SA': 0.03482047839042468,
#  'EDFO11B.SA': -0.08868797789228723,
#  'VIFI11.SA': -0.034658527816142946,
#  'VSHO11.SA': -0.2184194801435136,
#  'VTLT11.SA': 0.0334075723830735,
#  'VISC11.SA': 0.020792414668957572,
#  'BBRC11.SA': -0.06996427287832524,
#  'BBPO11.SA': -0.177952216346923,
#  'BNFS11.SA': -0.00661429424344319,
#  'TRXF11.SA': -0.011259071203748756,
#  'BICR11.SA': -0.003984078882466976,
#  'TEPP11.SA': -0.03169938524368767,
#  'RBVA11.SA': -0.1997768301641207,
#  'HBRH11.SA': 0.0,
#  'NSLU11.SA': 0.2903225806451613,
#  'PQDP11.SA': -0.058399444803703626,
#  'FIIB11.SA': 0.16350591569353376,
#  'LVBI11.SA': -0.05819226536417228,
#  'VVPR11.SA': -0.026213562604293084,
#  'PVBI11.SA': 0.0,
#  'CXTL11.SA': -0.3964285714285714,
#  'MFII11.SA': 0.07233468125326954,
#  'PATC11.SA': -0.15557771423495298,
#  'BCIA11.SA': -0.2401848353069218,
#  'RBVO11.SA': -0.7575312548556862,
#  'QMFF11.SA': 0.0,
#  'HUSC11.SA': -0.05567745085685484,
#  'SDIL11.SA': -0.037187435175019976,
#  'PQAG11.SA': 0.0,
#  'HLOG11.SA': -0.051904219283242715,
#  'HGRE11.SA': -0.007488089390592653,
#  'HGCR11.SA': -0.09985126240204385,
#  'URPR11.SA': 0.0,
#  'HGPO11.SA': 0.02714285433017713,
#  'HGRU11.SA': -0.02051183355752287,
#  'HGFF11.SA': -0.09639695155049151,
#  'VRTA11.SA': -0.08218755497457605,
#  'OUJP11.SA': -0.044166635583948205,
#  'PLCR11.SA': -0.006050323460878031,
#  'PATL11.SA': 0.0,
#  'XPLG11.SA': -0.05281872117747,
#  'BCRI11.SA': -0.0546110154315907,
#  'KNHY11.SA': -0.015739109205163044,
#  'KNIP11.SA': 0.013711869855957376,
#  'VCJR11.SA': 0.0072992700729927005,
#  'VOTS11.SA': -0.1111111111111111,
#  'RNDP11.SA': -0.23459583531386247,
#  'JSRE11.SA': -0.09226020253539365,
#  'NVHO11.SA': -0.47719952072813315,
#  'BBFI11B.SA': -0.2437436497908975,
#  'VILG11.SA': -0.009565210153934042,
#  'JPPA11.SA': -0.02822540684515928,
#  'CTXT11.SA': -0.23847778510244344,
#  'RNGO11.SA': -0.20325692769270245,
#  'RBIV11.SA': -0.06105994084582559,
#  'PLRI11.SA': -0.5866644134679543,
#  'CXCE11B.SA': -0.955951756685894,
#  'RBRD11.SA': -0.13274484250346316,
#  'AIEC11.SA': 0.0,
#  'SPTW11.SA': -0.005828750852024327,
#  'GTWR11.SA': -0.06256409995576255,
#  'FPAB11.SA': -0.1669902595897788,
#  'VINO11.SA': 0.012506252871995631,
#  'GALG11.SA': 0,
#  'PORD11.SA': -0.033617381379349755,
#  'IFIE11.SA': 0.0,
#  'LGCP11.SA': -0.004757218529976752,
#  'LUGG11.SA': -0.0360747720593604,
#  'FIGS11.SA': -0.08659087667651859,
#  'GRLV11.SA': 0.2125,
#  'HMOC11.SA': -0.04791666666666667,
#  'XPCM11.SA': -0.4737827102973897,
#  'SARE11.SA': -0.08859744246868237,
#  'XPSF11.SA': -0.00393779537220693,
#  'HFOF11.SA': -0.03877420729331406,
#  'HSML11.SA': -0.09163460364708534,
#  'HGBS11.SA': -0.0811321010629586,
#  'HGLG11.SA': 0.08342962773918182,
#  'CBOP11.SA': -0.02562346622740449,
#  'SADI11.SA': -0.17523003042647983,
#  'SHPH11.SA': -0.10233681126644736,
#  'HABT11.SA': 0.04886166357415631,
#  'RBED11.SA': -0.10470682603895408,
#  'SPVJ11.SA': 0,
#  'MALL11.SA': -0.04937547879638344,
#  'XPCI11.SA': -0.004333326551649305,
#  'ARRI11.SA': -0.005056145485867275,
#  'BPFF11.SA': -0.1728865633305815,
#  'KFOF11.SA': -0.08254389177288926,
#  'TGAR11.SA': 0.10443824067498175,
#  'KNCR11.SA': -0.1929309629834692,
#  'KNRI11.SA': -0.01942817253295503,
#  'HOSI11.SA': 0.018518500530834543,
#  'RDPD11.SA': -0.09124615476020133,
#  'RBFF11.SA': -0.0046821351774755755,
#  'NEWL11.SA': 0.0036538197444035457,
#  'MXRF11.SA': -0.05161294008552305,
#  'EURO11.SA': 0.12842081751102685,
#  'BARI11.SA': 0.02090911865234375,
#  'BRCO11.SA': -0.08526946351437749,
#  'AFCR11.SA': -0.024999971742983216,
#  'ABCP11.SA': -0.1753546488975334,
#  'XPPR11.SA': -0.10108338596845846,
#  'HPDP11.SA': -0.04433823712063812,
#  'HREC11.SA': 0,
#  'RBBV11.SA': 0.10515759248729765,
#  'GGRC11.SA': -0.03012910424774495,
#  'CRFF11.SA': -0.13174823367465233,
#  'THRA11.SA': 0.0012797888054105,
#  'CXRI11.SA': -0.8784495362448036,
#  'CPTS11.SA': 0.0,
#  'BTLG11.SA': -0.0033765963020420736,
#  'BREV11.SA': 0.03681820956143466,
#  'FLMA11.SA': -0.012987000923330156,
#  'SCPF11.SA': -0.28357828240868266,
#  'FATN11.SA': 0.0,
#  'QAGR11.SA': 0.003412917146252366,
#  'BRCR11.SA': -0.11636308253305908,
#  'MAXR11.SA': 0.14300810885321413,
#  'JRDM11.SA': -0.1420187665202814,
#  'HCTR11.SA': 0.02438229565439824,
#  'TORD11.SA': 0.0,
#  'BCFF11.SA': 0.13914580177381722,
#  'FAED11.SA': 0.0,
#  'MGFF11.SA': -0.14646464646464646,
#  'FEXC11.SA': -0.1407721033695344,
#  'BTCR11.SA': -0.16399823274971853,
#  'RBRL11.SA': 0.0,
#  'RBRP11.SA': 0.03799997965494792,
#  'RECR11.SA': 0.0,
#  'RECT11.SA': -0.06899932372591427,
#  'CEOC11.SA': -0.1913953381915425,
#  'NCHB11.SA': 0.0,
#  'CPFF11.SA': 0.01737499237060547,
#  'VGIP11.SA': 0.04077762924673157,
#  'RVBI11.SA': 0.00043632210926198135,
#  'CVBI11.SA': 0.03221232035913798,
#  'RBRF11.SA': -0.07228622330270668,
#  'MGHT11.SA': 0.0,
#  'BMLC11.SA': 0.0,
#  'RBRY11.SA': -0.1271186440677966,
#  'RBRR11.SA': -0.11500237908565264,
#  'IRDM11.SA': 0.07626769895727688,
#  'IBFF11.SA': 0.010230218452403602,
#  'VGIR11.SA': -0.03099081044734795,
#  'MCCI11.SA': -0.004403101386295368,
#  'HCRI11.SA': 0.45625,
#  'BLCP11.SA': 0.0,
#  'MORE11.SA': 0.0,
#  'MGCR11.SA': 0.0,
#  'TRNT11.SA': 0.11428571428571428,
#  'GCFF11.SA': 0.0}

# %%
def pega_setor(stock):
    return [x for x in df[symbols == stock]['Setor']]

stock_info_df = pd.DataFrame.from_dict(discount_dict, orient='index').reset_index()
stock_info_df.columns = ['ticker', 'discount']
stock_info_df['sector'] = [pega_setor(tick)[0] for tick in stock_info_df['ticker']]

stock_info_df
# Out:
#         ticker  discount               sector
# 0    FIVN11.SA -0.442336            Shoppings
# 1    BZLI11.SA -0.051948  Títulos e Val. Mob.
# 2    XTED11.SA -0.684670   Lajes Corporativas
# 3    ALMI11.SA -0.340606   Lajes Corporativas
# 4    DOMC11.SA -0.204739   Lajes Corporativas
# ..         ...       ...                  ...
# 195  BLCP11.SA  0.000000               Outros
# 196  MORE11.SA  0.000000  Títulos e Val. Mob.
# 197  MGCR11.SA  0.000000                  NaN
# 198  TRNT11.SA  0.114286   Lajes Corporativas
# 199  GCFF11.SA  0.000000  Títulos e Val. Mob.
#
# [200 rows x 3 columns]

# %%
def pega_dividendos(stock):
    return [x for x in df[symbols == stock]['dy']]

stock_info_df['dy'] = [pega_dividendos(tick)[0] for tick in stock_info_df['ticker']]

stock_info_df
# Out:
#         ticker  discount               sector      dy
# 0    FIVN11.SA -0.442336            Shoppings  0.0000
# 1    BZLI11.SA -0.051948  Títulos e Val. Mob.  0.0000
# 2    XTED11.SA -0.684670   Lajes Corporativas  0.0000
# 3    ALMI11.SA -0.340606   Lajes Corporativas  0.0000
# 4    DOMC11.SA -0.204739   Lajes Corporativas  0.0000
# ..         ...       ...                  ...     ...
# 195  BLCP11.SA  0.000000               Outros  0.0076
# 196  MORE11.SA  0.000000  Títulos e Val. Mob.  0.0081
# 197  MGCR11.SA  0.000000                  NaN  0.0066
# 198  TRNT11.SA  0.114286   Lajes Corporativas  0.0023
# 199  GCFF11.SA  0.000000  Títulos e Val. Mob.  0.0068
#
# [200 rows x 4 columns]

# %%
std_list = []

for tick in stock_info_df['ticker']:
    std_list.append(returns[tick].std())

stock_info_df['risk'] = std_list

stock_info_df.sort_values(by = 'discount').head(10)
# Out:
#          ticker  discount              sector      dy      risk
# 6     RBCB11.SA -0.959987              Outros  0.0000  0.039629
# 104  CXCE11B.SA -0.955952              Outros  0.0085  0.031617
# 35    FCFL11.SA -0.944976              Outros  0.0046  0.032266
# 7     RBDS11.SA -0.934040         Residencial  0.0038  0.033819
# 10    ATSA11.SA -0.900079           Shoppings  0.0018  0.035190
# 157   CXRI11.SA -0.878450             Híbrido  0.0048  0.031326
# 42    DMAC11.SA -0.799670         Residencial  0.0079  0.029422
# 72    RBVO11.SA -0.757531              Outros  0.0057  0.023781
# 2     XTED11.SA -0.684670  Lajes Corporativas  0.0000  0.031458
# 22   FAMB11B.SA -0.658722  Lajes Corporativas  0.0056  0.025927

# %%
import plotly.express as px
stock_info_df = stock_info_df.dropna()

# %%
fig = px.scatter(stock_info_df, x = 'risk', y = 'discount', color='sector', hover_name='ticker', log_x = True)
plotly.offline.plot(fig, filename='oportunidades.html')
# Out:
# 'oportunidades.html'
